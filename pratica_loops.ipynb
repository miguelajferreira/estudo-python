# %% [markdown]
# Atividade: Desenvolver um notebook para processar dados numéricos e
# consolidar os fundamentos da semana.
#
# Objetivo: Aplicar loops e funções em um contexto prático, exibindo
# resultados de forma organizada.
#
# Passos: Criar um notebook, escrever código para processar uma lista de
# valores (ex.: calcular soma ou média), usar print() para exibir resultados e
# documentar com Markdown.

# %%
comida = ["atum", "pessego", "maionese", "doces"]
Miguel = 23

#for loop
for char in comida:
    print("Delicious")

#while loops
while Miguel >= 30:
    Miguel + 1
else:
    print("You are old")

#funções
def calculadora():
    idade = int(input("Idade: "))
    if idade <= 17:
        print("You are young!")
    elif 18 <= idade <= 29:
        print("You are a young adult!")
    elif 30 <= idade <= 59:
        print("You are an adult!")
    else:
        print("You are old!")
    return idade

classifica_idade = calculadora()
print(classifica_idade)
# Out:
# Delicious
# Delicious
# Delicious
# Delicious
# You are old
# You are old!
# 70
