# %% [markdown]
# Atividade: Explorar listas e dicionários em um notebook para reforçar o aprendizado.
#
# Passos:
# Criar um novo notebook no VS Code e nomeá-lo (ex.: "pratica_estruturas.ipynb").
#
# Em uma célula, realizar operações com listas (ex.: criar uma lista,
# adicionar elementos, acessar posições).
#
# Adicionar uma célula Markdown com um título (ex.: "Estruturas de
# Dados") e uma descrição do que foi praticado.

# %%
#pratica_estruturas

best_games_of_all_time = ["Final Fantasy VII Saga", "Cyberpunk 2077", "Dark Souls", "Dark Souls 3"]

best_games_of_all_time.insert(3, "Dark Souls 2")

print(best_games_of_all_time)

best_games_of_all_time.pop(-2)

print(best_games_of_all_time)

best_games_of_all_time.append("Minecraft")

print(best_games_of_all_time)
# Out:
# ['Final Fantasy VII Saga', 'Cyberpunk 2077', 'Dark Souls', 'Dark Souls 2', 'Dark Souls 3']
# ['Final Fantasy VII Saga', 'Cyberpunk 2077', 'Dark Souls', 'Dark Souls 3']
# ['Final Fantasy VII Saga', 'Cyberpunk 2077', 'Dark Souls', 'Dark Souls 3', 'Minecraft']

# %% [markdown]
# Operações com listas:
#
# Criar uma lista: best_games_of_all_time = ["Final Fantasy VII Saga", "Cyberpunk 2077", "Dark Souls", "Dark Souls 3"]
#
# Adicionar na posição 3, o jogo Dark Souls 2: best_games_of_all_time.insert(3, "Dark Souls 2")
#
# Adiciona á ultima posição o jogo Minecraft: best_games_of_all_time.append("Minecraft")
#
# Retirar o jogo que está na posição -2: best_games_of_all_time.pop(-2)

# %% [markdown]
# Atividade: Praticar com dicionários
#
# Em uma célula, trabalhar com dicionários (ex.: criar um
# dicionário, adicionar pares chave-valor, recuperar valores).

# %%
rating_games = {"Final Fantasy VII: Saga": 9, "Cyberpunk 2077": 10, "Dark Souls": 10, "Dark Souls 3": 9, "Minecraft": "Legendary"}

print(rating_games)

print(rating_games["Final Fantasy VII: Saga"])
# Out:
# {'Final Fantasy VII: Saga': 9, 'Cyberpunk 2077': 10, 'Dark Souls': 10, 'Dark Souls 3': 9, 'Minecraft': 'Legendary'}
# 9
# <function bibliotec_of_games at 0x000001FAA098EE80>

# %% [markdown]
# Operações com dicionários:
#
# Criar um dicionário: rating_games = {"Final Fantasy VII: Saga": 9, "Cyberpunk 2077": 10, "Dark Souls": 10, "Dark Souls 3": 9, "Minecraft": "Legendary"}
#
# Devolver o score que atribui á variável que está dentro do dicionário, Final Fantasy VII: Saga = 9
